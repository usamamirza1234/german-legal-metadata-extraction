# %%
from pdf_extractor_with_ocr import PDFExtractorWithOCR
from optimise_code.optimisation import OptimizedMetadataExtractor
debug = False

# %%
extractor = OptimizedMetadataExtractor(debug=debug)
pdf_extractor = PDFExtractorWithOCR(debug=debug)
text = pdf_extractor.extract_text_from_pdf(pdf_path = "../pdfs/30s/30s/berufearchiv_5496.pdf", start_page=1, end_page=3)

if debug:
    print("Extracted Text: ", text)

metadata = extractor.extract_all_metadata(text)
if debug:
    print("\n" + "=" * 60)
    print("EXTRACTION RESULTS:")
    print("=" * 60)

result_dict = metadata.to_dict()
print(result_dict)
for key, value in result_dict.items():
    if value and key != 'raw_text_preview':
        print(f"{key.upper()}: {value}")
# Out:
# 📖 Processing page 1...
#    ✅ OCR extraction: 450 characters
# 📖 Processing page 2...
#    ✅ OCR extraction: 1128 characters
# 📖 Processing page 3...
#    ✅ OCR extraction: 1491 characters
# {'title': None, 'year': 1938, 'date': '1938-09-22T00:00:00', 'publisher': None, 'author': None, 'document_type': None, 'profession': None, 'confidence_scores': {}, 'raw_text_preview': None}
# YEAR: 1938
# DATE: 1938-09-22T00:00:00

# %%
extractor = OptimizedMetadataExtractor(debug=debug)
pdf_extractor = PDFExtractorWithOCR(debug=debug)
text = pdf_extractor.extract_text_from_pdf(pdf_path = "../pdfs/30s/30s/berufearchiv_5526.pdf", start_page=1, end_page=2)

if debug:
    print("Extracted Text: ", text)

metadata = extractor.extract_all_metadata(text)
if debug:
    print("\n" + "=" * 60)
    print("EXTRACTION RESULTS:")
    print("=" * 60)

result_dict = metadata.to_dict()
print(result_dict)
for key, value in result_dict.items():
    if value and key != 'raw_text_preview':
        print(f"{key.upper()}: {value}")
# Out:
# 📖 Processing page 1...
#    ✅ OCR extraction: 381 characters
# 📖 Processing page 2...
#    ✅ OCR extraction: 8 characters
# {'title': None, 'year': None, 'date': None, 'publisher': None, 'author': None, 'document_type': None, 'profession': None, 'confidence_scores': {}, 'raw_text_preview': None}

# %%
extractor = OptimizedMetadataExtractor(debug=debug)
pdf_extractor = PDFExtractorWithOCR(debug=debug)
text = pdf_extractor.extract_text_from_pdf(pdf_path = "../pdfs/30s/30s/berufearchiv_5542.pdf", start_page=1, end_page=7)

if debug:
    print("Extracted Text: ", text)

metadata = extractor.extract_all_metadata(text)
if debug:
    print("\n" + "=" * 60)
    print("EXTRACTION RESULTS:")
    print("=" * 60)

result_dict = metadata.to_dict()
print(result_dict)
for key, value in result_dict.items():
    if value and key != 'raw_text_preview':
        print(f"{key.upper()}: {value}")
# Out:
# 📖 Processing page 1...
#    ✅ OCR extraction: 37 characters
# 📖 Processing page 2...
#    ❌ No text found on page 2
# 📖 Processing page 3...
#    ✅ OCR extraction: 198 characters
# 📖 Processing page 4...
#    ❌ No text found on page 4
# 📖 Processing page 5...
#    ✅ OCR extraction: 1757 characters
# 📖 Processing page 6...
#    ✅ OCR extraction: 597 characters
# 📖 Processing page 7...
#    ✅ OCR extraction: 1567 characters
# {'title': None, 'year': 1939, 'date': '1939-04-27T00:00:00', 'publisher': None, 'author': None, 'document_type': None, 'profession': None, 'confidence_scores': {}, 'raw_text_preview': None}
# YEAR: 1939
# DATE: 1939-04-27T00:00:00

# %%
extractor = OptimizedMetadataExtractor(debug=debug)
pdf_extractor = PDFExtractorWithOCR(debug=debug)
text = pdf_extractor.extract_text_from_pdf(pdf_path = "../pdfs/30s/30s/berufearchiv_6317.pdf", start_page=1, end_page=2)

if debug:
    print("Extracted Text: ", text)

metadata = extractor.extract_all_metadata(text)
if debug:
    print("\n" + "=" * 60)
    print("EXTRACTION RESULTS:")
    print("=" * 60)

result_dict = metadata.to_dict()
print(result_dict)
for key, value in result_dict.items():
    if value and key != 'raw_text_preview':
        print(f"{key.upper()}: {value}")
# Out:
# 📖 Processing page 1...
#    ✅ OCR extraction: 971 characters
# {'title': None, 'year': None, 'date': None, 'publisher': None, 'author': None, 'document_type': None, 'profession': None, 'confidence_scores': {}, 'raw_text_preview': None}

# %%
extractor = OptimizedMetadataExtractor(debug=debug)
pdf_extractor = PDFExtractorWithOCR(debug=debug)
text = pdf_extractor.extract_text_from_pdf(pdf_path = "../pdfs/30s/30s/berufearchiv_6322.pdf", start_page=1, end_page=1)

if debug:
    print("Extracted Text: ", text)

metadata = extractor.extract_all_metadata(text)
if debug:
    print("\n" + "=" * 60)
    print("EXTRACTION RESULTS:")
    print("=" * 60)

result_dict = metadata.to_dict()
print(result_dict)
for key, value in result_dict.items():
    if value and key != 'raw_text_preview':
        print(f"{key.upper()}: {value}")
# Out:
# 📖 Processing page 1...
#    ✅ OCR extraction: 591 characters
# {'title': None, 'year': 1938, 'date': '1938-03-01T00:00:00', 'publisher': None, 'author': None, 'document_type': None, 'profession': None, 'confidence_scores': {}, 'raw_text_preview': None}
# YEAR: 1938
# DATE: 1938-03-01T00:00:00

# %%
extractor = OptimizedMetadataExtractor(debug=debug)
pdf_extractor = PDFExtractorWithOCR(debug=debug)
text = pdf_extractor.extract_text_from_pdf(pdf_path = "../pdfs/30s/30s/berufearchiv_6384.pdf", start_page=1, end_page=3)

if debug:
    print("Extracted Text: ", text)

metadata = extractor.extract_all_metadata(text)
if debug:
    print("\n" + "=" * 60)
    print("EXTRACTION RESULTS:")
    print("=" * 60)

result_dict = metadata.to_dict()
print(result_dict)
for key, value in result_dict.items():
    if value and key != 'raw_text_preview':
        print(f"{key.upper()}: {value}")
# Out:
# 📖 Processing page 1...
#    ✅ OCR extraction: 499 characters
# 📖 Processing page 2...
#    ✅ OCR extraction: 1364 characters
# 📖 Processing page 3...
#    ✅ OCR extraction: 1385 characters
# {'title': None, 'year': 1938, 'date': '1938-11-11T00:00:00', 'publisher': None, 'author': None, 'document_type': None, 'profession': None, 'confidence_scores': {}, 'raw_text_preview': None}
# YEAR: 1938
# DATE: 1938-11-11T00:00:00

# %%
extractor = OptimizedMetadataExtractor(debug=debug)
pdf_extractor = PDFExtractorWithOCR(debug=debug)
text = pdf_extractor.extract_text_from_pdf(pdf_path = "../pdfs/30s/30s/30s_feinpolierer_1937_pruefungsanforderungen.pdf", start_page=1, end_page=1)

if debug:
    print("Extracted Text: ", text)

metadata = extractor.extract_all_metadata(text)
if debug:
    print("\n" + "=" * 60)
    print("EXTRACTION RESULTS:")
    print("=" * 60)

result_dict = metadata.to_dict()
print(result_dict)
for key, value in result_dict.items():
    if value and key != 'raw_text_preview':
        print(f"{key.upper()}: {value}")
# Out:
# 📖 Processing page 1...
#    ✅ OCR extraction: 388 characters
# {'title': None, 'year': 1937, 'date': '1937-03-01T00:00:00', 'publisher': None, 'author': None, 'document_type': None, 'profession': None, 'confidence_scores': {}, 'raw_text_preview': None}
# YEAR: 1937
# DATE: 1937-03-01T00:00:00
