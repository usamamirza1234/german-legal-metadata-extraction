# %%
from pdf_extractor_with_ocr import PDFExtractorWithOCR
from optimise_code.optimisation import OptimizedMetadataExtractor


debug = True
extractor = OptimizedMetadataExtractor(debug=debug)
pdf_extractor = PDFExtractorWithOCR(debug=debug)
text = pdf_extractor.extract_text_from_pdf(pdf_path = "../pdfs/30s/30s/berufearchiv_5496.pdf", start_page=1, end_page=3)

if debug:
    print("Extracted Text: ", text)

metadata = extractor.extract_all_metadata(text)
if debug:
    print("\n" + "=" * 60)
    print("EXTRACTION RESULTS:")
    print("=" * 60)

result_dict = metadata.to_dict()
print(result_dict)
for key, value in result_dict.items():
    if value and key != 'raw_text_preview':
        print(f"{key.upper()}: {value}")
# Out:
# ✅ PDFExtractorWithOCR.init PDF Extractor with OCR initialized
# ✅ Tesseract OCR is available
# ✅ PDFExtractorWithOCR.extract_text_from_pdf:
# ✅ ExtractorOCRText.extract_text_from_pdf:
# 📄 Processing pages 1 to 3 of 4 ..... in berufearchiv_5496.pdf
# 📖 Processing page 1...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 1 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_5496\page_1.png
# Text after inversion:
#    ✅ OCR extraction: 439 characters
# 📖 Processing page 2...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 2 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_5496\page_2.png
# Text after inversion:
#    ✅ OCR extraction: 1129 characters
# 📖 Processing page 3...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 3 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_5496\page_3.png
# Text after inversion:
#    ✅ OCR extraction: 1498 characters
# Extracted Text:
# --- Page 1 (OCR) ---
# Berufs-
# Eignungsanforderungen
#
# für den Eintritt in den Lehrberuf
#
# Schmuckstemfasser
# bearbeitet vom
#
# Deutschen Ausschuß für Technisches Schulweer (Datfch) E.V.
# · Berlin NW7
#
# im Einvernehmen
# mit der
# Deutschen Arbeitsfront
# der
#
# Neichsgruppe Industrie
#
# . und der
#
# Arbeitsgemeinschaft der Industrie- und Handelskammern
# in der Neichswirtfchaftskammer
#
# (Stcmd vom 22. September 1938)
#
# Verlag von B.G.Teubner in Leipzig und Berlin
#
# Pest-Nu 13 650
#
# --- Page 2 (OCR) ---
# Berufseignungsanforderungen
#
# fiir den Eintritt in den Lehrberuf
#
# Schmucksieinfasser
#
# (Die Begriindungen für die einzelnen Eignungtsanforderungen sind aus den
# Berufsanforderungen abgeleitet, wie sie sich aus dem Arbeitsgebiet, der Berufs-
# ausiibung sowie den besonderen Arbeitsbedingungen des Facharbeiters ergeben.)
#
# Notwendig :
#
# Ertvünscht:
#
# Ausschließend :
#
# Notwendig :
#
# Erwünscht :
#
# Vorbildungsmäßige Anforderungen
#
# Möglichst abgeschlossene Volksschulbildung oder
# gleichwertige Allgemeinbildung bei Abgängern
# aus anderen Schulen.
#
# Sportliche Vorbildung:
#
# Ausgleieh gegen die sitzende Arbeitsweise.
#
# Zeichnerische Fertigkeiten.
#
# Hilfst-, Sehschwachen- und Blindenschulbildung
# (Schwerhörige und Taubstumme können den Be-
# ruf ausüben!).
#
# -
#
# Körperliche Anforderungen
#
# Keine besonderenAnforderungen an den Körperbau:
# Der Schmucksteinfasser hat nur leichte körperliche Arbeit
# in sitzender Arbeitsweise zu leisten.
#
# Regelrechte Sehschärfe (1nindestens 2X3 beiderseits):
# Erkennen feiner und feinster Linien und Bohrungen in
# glänzendem Metall auch bei künstlichem Licht.
#
# Farbtüchtigkeit:
#
# Unterscheiden der einzelnen Schmuck-steine.
#
# --- Page 3 (OCR) ---
# O
#
# Ausfchließend:Lungentuberkulose (offene oder fortschreitende);
#
# Notwendig: —
#
# andere chronisch verlaufende Erkrankungen der
# Lungen und der Luftwege.
#
# Durch Gläser nicht korrigierbare Brechungsfehler
# (Kurzsichtigkeit nicht ausschließend).
#
# Farbenblin«dheit.
#
# Einäugigkeit.
#
# Chronifche, zu Rückfällen neigende Erkrankungen
# der Haut, insbesondere Ekzeme oder angeborene
# Neigung hierzu. «
#
# Chronifch organische Nervenleiden mit Motili-
# tätsstörungen an den oberen Gliedmaßen.
#
# Chronische Gelenkerkrankungen mit Bewegungs-
# einfchränkungen an den oberen Gliedmaßen.
#
# Wirbelsäulenverkrümmung Z. und 3. Grades (Sitz-
# arbeit!).
#
# Schweißhand.
#
# Fehlen des Daumens oder von mehr als einem
# Finger an der Arbeitshand.
#
# Seelifche Anforderungen
#
# Sinn für Formgestaltungx
# Übertragen von Zeichnungen. Fassen der Schmucksteine
# nach der Arbeit des Goldschmiedes, hierbei kommt es auf
# eine leichte und elegante Linienführung an. Genaues und
# formgerechtes Einpasfen. Der Schmucksteinfasser hat auch
# darauf zu achten, daß der Schmuckstein voll zur Geltüng
# kommt.
#
# Handgeskhicklichkeit (leichte, ruhige, sichere Hand;
#
# Gefühl für fein abgestimmte Kraftimpulse):
#
# Bearbeiten der Metalle mit Stichel, Bohrer und anderen
# Handwerkszeugen auch in kleinsten Formen.
#
# Genaue, sorgfältige und an einen festen Arbeits-
# platz gebundene Arbeitsweife;
#
# Daueraufmerkfamkeit (auch bei kniffligster Klein-
# arbeit): «
# Der Schmucksteinfasser hatdarauf Nückf icht zunehmen, daß
# die Arbeit des Goldfchmiedes von ihm nicht verdorben wird.
#
# 🔍 Extracting all metadata...
#
# ============================================================
# EXTRACTION RESULTS:
# ============================================================
# {'title': None, 'year': 1938, 'date': '1938-09-22T00:00:00', 'publisher': None, 'author': None, 'document_type': None, 'profession': None, 'confidence_scores': {}, 'raw_text_preview': None}
# YEAR: 1938
# DATE: 1938-09-22T00:00:00

# %%
debug = True
extractor = OptimizedMetadataExtractor(debug=debug)
pdf_extractor = PDFExtractorWithOCR(debug=debug)
text = pdf_extractor.extract_text_from_pdf(pdf_path = "../pdfs/30s/30s/berufearchiv_5526.pdf", start_page=1, end_page=3)

if debug:
    print("Extracted Text: ", text)

metadata = extractor.extract_all_metadata(text)
if debug:
    print("\n" + "=" * 60)
    print("EXTRACTION RESULTS:")
    print("=" * 60)

result_dict = metadata.to_dict()
print(result_dict)
for key, value in result_dict.items():
    if value and key != 'raw_text_preview':
        print(f"{key.upper()}: {value}")
# Out:
# ✅ PDFExtractorWithOCR.init PDF Extractor with OCR initialized
# ✅ Tesseract OCR is available
# ✅ PDFExtractorWithOCR.extract_text_from_pdf:
# ✅ ExtractorOCRText.extract_text_from_pdf:
# 📄 Processing pages 1 to 3 of 20 ..... in berufearchiv_5526.pdf
# 📖 Processing page 1...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 1 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_5526\page_1.png
# Text after inversion:
#    ✅ OCR extraction: 381 characters
# 📖 Processing page 2...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 2 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_5526\page_2.png
# Text after inversion:
#    ❌ No text found on page 2
# 📖 Processing page 3...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 3 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_5526\page_3.png
# Text after inversion:
#    ✅ OCR extraction: 1492 characters
# Extracted Text:
# --- Page 1 (OCR) ---
# Industrie-
# Facharbeiterausbildung
#
# Berufsbildungsplan
# für den Lehrberuf
#
# Schokolademacher
#
# bearbeitet vom
#
# Deutschen Ausschuß für Technisches Schulwesen E. V. (Datsch)
# Berlin NW 7
#
# im Auftrage der
# Reichsgruppe Industrie
# und der
#
# . Arbeitsgemeinschaft der Industrie- und Handelskammern
# in der Reichswirtschaftskammer
#
# Verlag und Druck von B. G. Teubner in Leipzig und Berlin
#
# 11078
#
# --- Page 3 (OCR) ---
# Berufsbild des Schokolademachers
#
# (für die praktische Ausbildung)
# Lehrzeit: 3 Jahre
#
# Arbeitsgebiet des Facharbeiters:
# Bearbeiten der Kakaobohnen und Hex-stellen von Kakaoerzeug-
# nissen, im besonderen von Schokolade, Kakaopulver, Kakao-
# masse, Kakaobutter und Überzugsmasse.
#
# Fertigkeiten, die der Lehrling in der Lehrzeit erwerben soll:
#
# NotwendigetBeurteilen und Behandeln der zu verarbeitenden Stoffe.
#
# Bedienen der Vorreinigungsmaschine, des Kakaorösters, der
# Brech- und Reinigungsmaschine und der Keimauslesemaschine
# zum Reinigen, Rösten und Brechen von Kakaobohnen.
#
# Behandeln des Kakaos zum Zwecke des Aufschließens.
#
# Bedienen der Drillingsmühlen und Kakaowalzen zum Mahlen
# und Walzen von gebrochenen Kakaobohnen.
#
# Bedienen der Kakaobutterpressen zum Abpressen und Filtern
# von Kakaobutter.
#
# Bedienen des Kakaokuchenbrechers und Pulverisators sowie
# der Siebanlage zum Brechen, Sieben und Pulverisieren von
# Kakaopreßkuchen.
#
# Einstellen und Bedienen der Maschinen zum Anfetzen, Mc-
# langieren, Walzen, Conchieren und Temperieren von Schoko-
# lademassen.
#
# Temperieren und Behandeln der Formen.
#
# Ein- und Ausformen von Schokolade.
#
# Abpacken von Kakaopulver und Verpacken Von Schokolade, auch
# mit Maschinen.
#
# Reinigen und Pflegen der Maschinen und Einrichtungen
#
# Erwünschte: Dekorieren mit Schokolade.
#
# Bedienen des Bakuumkneters für Schokoladen.
#
# Herstellen von Pralineneinlagen.
#
# Einstellen und Bedienen der Maschinen zum Überziehen von
# Pralinen u. dgl.
#
# Einfache Maschinenschlosserarbeiten.
#
# 🔍 Extracting all metadata...
#
# ============================================================
# EXTRACTION RESULTS:
# ============================================================
# {'title': None, 'year': None, 'date': None, 'publisher': None, 'author': None, 'document_type': None, 'profession': None, 'confidence_scores': {}, 'raw_text_preview': None}

# %%
debug = True
extractor = OptimizedMetadataExtractor(debug=debug)
pdf_extractor = PDFExtractorWithOCR(debug=debug)
text = pdf_extractor.extract_text_from_pdf(pdf_path = "../pdfs/30s/30s/berufearchiv_5542.pdf", start_page=1, end_page=8)

if debug:
    print("Extracted Text: ", text)

metadata = extractor.extract_all_metadata(text)
if debug:
    print("\n" + "=" * 60)
    print("EXTRACTION RESULTS:")
    print("=" * 60)

result_dict = metadata.to_dict()
print(result_dict)
for key, value in result_dict.items():
    if value and key != 'raw_text_preview':
        print(f"{key.upper()}: {value}")
# Out:
# ✅ PDFExtractorWithOCR.init PDF Extractor with OCR initialized
# ✅ Tesseract OCR is available
# ✅ PDFExtractorWithOCR.extract_text_from_pdf:
# ✅ ExtractorOCRText.extract_text_from_pdf:
# 📄 Processing pages 1 to 8 of 38 ..... in berufearchiv_5542.pdf
# 📖 Processing page 1...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 1 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_5542\page_1.png
# Text after inversion:
#    ❌ No text found on page 1
# 📖 Processing page 2...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 2 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_5542\page_2.png
# Text after inversion:
#    ❌ No text found on page 2
# 📖 Processing page 3...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 3 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_5542\page_3.png
# Text after inversion:
#    ✅ OCR extraction: 144 characters
# 📖 Processing page 4...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 4 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_5542\page_4.png
# Text after inversion:
#    ❌ No text found on page 4
# 📖 Processing page 5...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 5 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_5542\page_5.png
# Text after inversion:
#    ✅ OCR extraction: 1759 characters
# 📖 Processing page 6...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 6 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_5542\page_6.png
# Text after inversion:
#    ✅ OCR extraction: 701 characters
# 📖 Processing page 7...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 7 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_5542\page_7.png
# Text after inversion:
#    ✅ OCR extraction: 1568 characters
# 📖 Processing page 8...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 8 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_5542\page_8.png
# Text after inversion:
#    ❌ No text found on page 8
# Extracted Text:
# --- Page 3 (OCR) ---
# Fakhtiche
#
# Vorschriften zur Regelung
# des Lehrlingswsfms im
# Schornsteinfegerhandwerk
#
# XI M-
#
# szandwerker-Verlagshaus Hans Holzmamh Verlin SW 68
#
#
# --- Page 5 (OCR) ---
# Illhalcsvckzclchms
#
# I· Allgemeine Bestimmungen Sei-e
# § 1 Zuständigkeit . . . . . . . . . . . . . . 7
# § 2 Eignungsbedingungen . . . . . . · . 7
# I Nassifche und körperliche Anforderungen . . . . . . 9
# II Schulkenntnisse . . 11
# III Anforderungen für die Cignungsuntersuchungen durch
# die Arbeitsämter . . . . 11
# IV. Lebensalter und Neichsangehörigkeit . . . . . . . 11
# V. Nachweis der Eignung. . . . . . . . . . 12
# § 3 Lehrzeitdauer . . . . . . . . . . . . . . . . . 12
# § 4 Lehrlingshöchstzahl. . . . . . . . . . . 12
# § 5 Anforderungen an den Lehrbetrieb . · . . . . . . · . 12
# § 6 Verwandtschaft . . . . . . . . . . . . . . . 14
# II. Verufsausbildung
# § 7 Grundforderungen . . . . . . . . 14
# § 8 Verufsausbildungsplan der Meisterlehre . . . . . . . . 14
# § 9 Lehrplan der Berufssch chlu e . . . . . . . . . . 15
# § 10 Werkstattwochenbuch . . . . . . . . . . . . . . 15
# III Swifchenpriifung
# § 11 Allgemeine-Z ur Swi enprüfung . . . . . . . . . . 16
# § 12 Praktische Pküfung sch . . . . 17
# § 13 Verfahren zur Abnahme der praktischen Prufung . . . . 17
# § 14 Theoretische Prüfung. . . . . . . 18
# IV. Gesellenprüfung
# § 15 Allgemeines zur Gesellenprüfuug . . . . . . . . . . 19
# § 16 Mindestanforderungen . . . . . . . 19
# 1 Herrichten und Vorbereiten von Kehrgeräten . . 19
# 2. Meinigen von Schornsteinen und Feuerungsanlagen durch
# Besteigen . . 20
# 3 Aus-führen von Kehrarbciten an Schornsteinen und Feu-
# erungsanlagen, die nicht beftiegen werden . . . 0
# § 17 Arbeitsproben . . . . . . . . 22
# § 18 Gesellenstück . . 22
# § 19 Verfahren zur Anfertigung und Äbnahme des Gesellenstücks 23
# § 20 Verfahren für die Durchführung der Arbeitsproben. . . 23
# § 21 Verfahren zur lenahme der theoretischen Prüfung. . . . 24
# § 22 Prüfungsgebiete für die theoretische Prüfung . . . . . . 25
#
#
# --- Page 6 (OCR) ---
# A. Fachtechnischer Teil
# Bericht über die Arbeitsproben . . . . .
# Arbeitskunde, Werkzeuge und Geräte . .
# Bau- und feuerpolizeiliche Bestimmungen unter Veriick-
# sichtigung der Vaukunde . . . . . . . .
# Wärmelehre und Heiztechnik . .
# Nechtliche Vorschriften über das Schornsteinfegerwefen
#
# B. Kaufmännischer Teil
# . Buchführung . . . . . . . . . . . . . . .
# Zahlungsverkehr . . . . . . . . . . . . . . .
# Schriftverkehr . . . . . . . . . . . .
# C. Allgemein- theoretischer Teil
#
# l. Allgemeine Kenntnisse . .
#
# II. Geschichtliche Bedeutung und Organisation des Hand-
# werks . . . . . . .
#
# IlI Lehrlings-, Gesellen-— und Meisterwesen . .
#
# IV. Rechts-, Versicherungs- und Steuerwefen .
#
# As Pp-
#
# pp-
#
# 29
#
# 30
# 31
# 31
#
# --- Page 7 (OCR) ---
# Vorwort
#
# Der Neichswirtschaftsniinister hat sich mit den Fachlichen
# Vorschriften zur Regelung des Lehrlingswesens im Schornstein-
# fegerhandwerk mit dem Erlaß IIl sW 10 861J39 vom 22. April
# 1939 einverstanden erklärt. Sie treten mit Wirkung vom 1.Juli
# 1939 in Kraft. Lehrverträge sind von diesem Zeitpunkt an ent-
# sprechend diesen Bestimmungen abzuschließen.
#
# Durch die Fachlichen Vorschriften werden die Lehrlings-
# ordnungen und Gesellenpriisungsordnungen der Handwerks-
# kammern insoweit außer Kraft gesetzt, als durch die Fachlichen
# Vorschriften anderes bestimmt wird. Hierdurch werden nicht nur
# die Berufsausbildung, sondern auch die Lehrzeitdaner und die
# Lehrlingshöchstzahlen für das ganze Neich einheitlich geregelt.
#
# Mit dem Erlasz dieser Vorschriften und dem im August 1936
# erfolgten Crlasz der Fachlichen Vorschriften für die Meister-
# priifung verfügt das Schornftcinfegerhandwerk«nunmehr über
# eine einheitliche Grundlage, nach der alle sachlichen Fragen der
# Berufsausbildung von Anbeginn der Lehre bis zur Ablegnng
# der Meisterprüfung geregelt sind.
#
# Nachdem der Neichsstand des Deutschen Handwerks nnd der
# Neichsinnungsverband des Sehornsteinfegerhandwerks diese
# Grundlagen geschaffen haben, ist es Aufgabe der Handwerks-
# kammern, Jnnungen und jedes einzelnen Lehrmeisters, dafür
# Sorge zu tragen, dasz sie in der Praxis volle Anwendng finden
# und die Ausbildung des Nachwuchses gründlich und umfassend
# erfolgt, um das Ziel der Steigerung der Leistung im Handwerk
# mit Erfolg zu erreichen.
#
# Berlin, den 27. April 1939.
#
# Schramm, M.d.N.,
# Neichshandwerksmeister.
#
#
# 🔍 Extracting all metadata...
#
# ============================================================
# EXTRACTION RESULTS:
# ============================================================
# {'title': None, 'year': 1939, 'date': '1939-04-27T00:00:00', 'publisher': None, 'author': None, 'document_type': None, 'profession': None, 'confidence_scores': {}, 'raw_text_preview': None}
# YEAR: 1939
# DATE: 1939-04-27T00:00:00

# %%
debug = True
extractor = OptimizedMetadataExtractor(debug=debug)
pdf_extractor = PDFExtractorWithOCR(debug=debug)
text = pdf_extractor.extract_text_from_pdf(pdf_path = "../pdfs/30s/30s/berufearchiv_6317.pdf", start_page=1, end_page=3)

if debug:
    print("Extracted Text: ", text)

metadata = extractor.extract_all_metadata(text)
if debug:
    print("\n" + "=" * 60)
    print("EXTRACTION RESULTS:")
    print("=" * 60)

result_dict = metadata.to_dict()
print(result_dict)
for key, value in result_dict.items():
    if value and key != 'raw_text_preview':
        print(f"{key.upper()}: {value}")
# Out:
# ✅ PDFExtractorWithOCR.init PDF Extractor with OCR initialized
# ✅ Tesseract OCR is available
# ✅ PDFExtractorWithOCR.extract_text_from_pdf:
# ✅ ExtractorOCRText.extract_text_from_pdf:
# 📄 Processing pages 1 to 1 of 1 ..... in berufearchiv_6317.pdf
# 📖 Processing page 1...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 1 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_6317\page_1.png
# Text after inversion:
#    ✅ OCR extraction: 970 characters
# Extracted Text:
# --- Page 1 (OCR) ---
# Beruksbild des teppichivebvers
#
# (für die praktische Ausbildung)
# Lehrzeit: z Jahre
#
# Arbeitsgebiet des cepviclnvebersx
#
# Weben z.B. folgender Arten: Arminster-, mechanisch
# Smyrna-, Greifer-, Royalarminster-, Druck-, Tour-
# nay-, Bonatti-, Iuteteppiche, Läufer u. a. m.
#
# Vorrichten und Einrichten der Webstühle.
#
# Pflegen und Instandhalten der Arbeitsmaschinen und
# Geräte.
#
# keetiglteitem die der Lehrling in der Lehrzeit erwerben toll-
# Notwendige: Spulen.
#
# Kennenlernen des Kettenbäumens.
#
# Kennenlernen des Appretierens.
#
# Rennenlernen des Kartenschlagens.
#
# Kennenlernen des Stopfens.
#
# Kennenlernen der Arten und Bezeichnungen der Werk-
# stoffe.
#
# Einfache Arbeiten in Holz und Eisen.
#
# Helfen bei Instandsetzungsarbeiten.
#
# Anknoten.
#
# Fadeneinziehem
#
# Gelesemachen.
#
# Blattstechen.
#
# Rutenausrichten.
#
# Vorrichten und Einrichten des Webstuhles.
#
# Weben von mehreren Arten von Teppichen.
#
# Fehlerbeseitigem
#
# Pflegen und Instandhalten der Arbeitsmaschinen und
# Geräte.
#
# Erwünfchie: —
#
# 172
#
# 🔍 Extracting all metadata...
#
# ============================================================
# EXTRACTION RESULTS:
# ============================================================
# {'title': None, 'year': None, 'date': None, 'publisher': None, 'author': None, 'document_type': None, 'profession': None, 'confidence_scores': {}, 'raw_text_preview': None}

# %%
debug = True
extractor = OptimizedMetadataExtractor(debug=debug)
pdf_extractor = PDFExtractorWithOCR(debug=debug)
text = pdf_extractor.extract_text_from_pdf(pdf_path = "../pdfs/30s/30s/berufearchiv_6322.pdf", start_page=1, end_page=3)

if debug:
    print("Extracted Text: ", text)

metadata = extractor.extract_all_metadata(text)
if debug:
    print("\n" + "=" * 60)
    print("EXTRACTION RESULTS:")
    print("=" * 60)

result_dict = metadata.to_dict()
print(result_dict)
for key, value in result_dict.items():
    if value and key != 'raw_text_preview':
        print(f"{key.upper()}: {value}")
# Out:
# ✅ PDFExtractorWithOCR.init PDF Extractor with OCR initialized
# ✅ Tesseract OCR is available
# ✅ PDFExtractorWithOCR.extract_text_from_pdf:
# ✅ ExtractorOCRText.extract_text_from_pdf:
# 📄 Processing pages 1 to 3 of 5 ..... in berufearchiv_6322.pdf
# 📖 Processing page 1...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 1 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_6322\page_1.png
# Text after inversion:
#    ✅ OCR extraction: 598 characters
# 📖 Processing page 2...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 2 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_6322\page_2.png
# Text after inversion:
#    ✅ OCR extraction: 1992 characters
# 📖 Processing page 3...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 3 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_6322\page_3.png
# Text after inversion:
#    ✅ OCR extraction: 169 characters
# Extracted Text:
# --- Page 1 (OCR) ---
# BERUFSAUSBILDUNC IN DER INDUSTRlE
#
# J ugendlichchu leildung
#
# Präfungsanfordetsungen
#
# fiir den Lehrberuf
#
# f.l«el)1)i0lmss(-l)0r
#
# bearbeitet vym
#
# Reichsjnstilut für Berufssuslsildung in Handel und Gewerbe
# Gemeinscliaktsorgan tlck Organisation tlck gewerblichen Wirtschaft
# uml der Denkst-liest Arbeits-from
#
# Am 19. März 1938 als industrieller Lelirljeruf mit-klimmt
# durch die Reichsgruppe Industrie mul die
# Ärbeilsgemeinscltaft tlcr Industrie· uml Hamlelsliannncrn
#
# in der Reichswiktscltuktslcammet-
#
# Slimd vmn l. Miit-Z 1938
#
# verlag und Druck von B. G.Tcul)n(kk in Leipzig und Berlin
#
# Erst-Am P172-17
#
# --- Page 2 (OCR) ---
# Betsufsbild des Teppichwebers
#
# (für die heim-bliebe- Ausbildung)
#
# Lehrzeitt 3 Jahre
#
# Arbeitsgebiet des Teppichwebeks
#
# Als Arbeitsgebiet Sind hier die typisehen Arbeiten de- etliklirenen Beruf-trügen ausgefüllt-L sei-mit sie zur
# Kennzeinhnung und Abgrenzung des Berufs-.- ektunlerlielt sind. l-.ine gegebenenfkslls notwendige Zeilweise
# Bose kiinlcungf auf läinzeltiiliglceitem bestimmte ArheilcekzeuszniksMu Werkstnilc otlek Arbeitsversnhken ist
# nicht besonders zum Ausdruck gebracht. weil durch tlie Breite und Einheitlielzlceit der vorgecehriehenen
# Ausbildung erreicht wird. ils-Ü jeder lierutLtriiLek neu-h einer angennsscenenAuliuifzeit innerhalb des ges-innen
# Arbeitsgebietes umselzlmr ist«
#
# vWeben z· B. folgender Arten: Äxtninster-, mechanisch smyrna-, Greises-,
# Royalaxmjnster-, Druck-, T()urnay-, Bunds-, Juteteppiche, Läufe-r u· a. m.
#
# Vol-richten und JCinriehten der Weljstijhlm
#
# Pllegen und Instandhalten der Akheitsgeräite und Maschinen-
#
# Fertigkeiten und Kenntnisse, die in tler Lehkzeit zuvermitteln sind
#
# Kenntnisse, die mit den- lelerncn der nachstellen-l genannten l-"ektigl(eiten Zwiingsltiulig verbunden und
# X""(1ki-uscet7.un;( für die richtig-c Anwendung llek Fertigkeiten Sind, werden hier nicht gesondert unf-
# gekühth Dies bezieht sieh isueli inif die mit der Berufstätigkeit , sumnienhiingenden Arbeit-Schutz-
# lnsstimmungen (-.. B. gewerbepolizeiliehe Bestimmungen. Berufs-genossenscchnstwol-schritten Jugend-
# schutzgeselz). Alle erforderlichen Kenntniss-e net-den ehe-Ho wit- tleis l"1nlimg der Fertigkeiten im
#
# lierujssbilcluugsplmz ins-mischen »Hiqu
#
# .
# N 0twondige:
#
# Unterschcidcn und Beut-teilen der spinnstolXe hinsichtlich ihrer Eigen-
# schaften, Verarbeitungss und Verwendungsmöglichlceiton.
#
# Spulen-
#
# lccnnen des Kottenbiiutnens.
# Kennen des Appretieretis.
#
# Kennen des Kartens(shlagens.
# Kenncn des stopfc118.
#
# Einfachc Arbeiten in Holz und Eisen.
# llelfen bei InsLands-setzungsarlnrjten.
# A11kn0ten.
#
# Fadeneinziehem
#
# Celesemacheih
#
# Blattstechen.
#
# Rittenausrichteih
#
# --- Page 3 (OCR) ---
# Vorrjchten und Einrichtcn des erbstuhles
# XVeben mehrerer Artpn von Teppjcrhem
# Fehlerbeseitigen.
#
# Pflegen nnd Instandhalten der Arbeitsgeräte und Maschinen·
#
# Ekwünschte:
#
# 🔍 Extracting all metadata...
#
# ============================================================
# EXTRACTION RESULTS:
# ============================================================
# {'title': None, 'year': 1938, 'date': '1938-03-19T00:00:00', 'publisher': None, 'author': None, 'document_type': None, 'profession': None, 'confidence_scores': {}, 'raw_text_preview': None}
# YEAR: 1938
# DATE: 1938-03-19T00:00:00

# %%
debug = True
extractor = OptimizedMetadataExtractor(debug=debug)
pdf_extractor = PDFExtractorWithOCR(debug=debug)
text = pdf_extractor.extract_text_from_pdf(pdf_path = "../pdfs/30s/30s/berufearchiv_6384.pdf", start_page=1, end_page=3)

if debug:
    print("Extracted Text: ", text)

metadata = extractor.extract_all_metadata(text)
if debug:
    print("\n" + "=" * 60)
    print("EXTRACTION RESULTS:")
    print("=" * 60)

result_dict = metadata.to_dict()
print(result_dict)
for key, value in result_dict.items():
    if value and key != 'raw_text_preview':
        print(f"{key.upper()}: {value}")
# Out:
# ✅ PDFExtractorWithOCR.init PDF Extractor with OCR initialized
# ✅ Tesseract OCR is available
# ✅ PDFExtractorWithOCR.extract_text_from_pdf:
# ✅ ExtractorOCRText.extract_text_from_pdf:
# 📄 Processing pages 1 to 3 of 4 ..... in berufearchiv_6384.pdf
# 📖 Processing page 1...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 1 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_6384\page_1.png
# Text after inversion:
#    ✅ OCR extraction: 471 characters
# 📖 Processing page 2...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 2 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_6384\page_2.png
# Text after inversion:
#    ✅ OCR extraction: 1365 characters
# 📖 Processing page 3...
# ✅ ExtractorOCRText.extract_with_improved_ocr:
#       🖼️ Converting page 3 to high-quality image...
# 💾 Saved original image as output_dir\berufearchiv_6384\page_3.png
# Text after inversion:
#    ✅ OCR extraction: 1374 characters
# Extracted Text:
# --- Page 1 (OCR) ---
# Berufs-
# Eignungsanforderungen
#
# für den Eintritt in den Lehrberuf
# so
#
# Thermometerjustierer
#
# (Thermometerfchreiber)
#
# bearbeitet vom
#
# Deutschen Ausschuß für Technisches Schulweer (Datsch) E.V.
# Berlin NW 7
#
# im Einvernehmen
# mit der
#
# Deutschen Arbeitsfront
# der
#
# Reichsgruppe Industrie
#
# O und der
# ’ Arbeitsgemeinfchaft der Industrie- und Handelslammern
# in der Reichswirtfchastskammer .
#
# (Stcmd vom 11. November 1938)
#
# Verlag von B.G.Teubner in Leipzig und Berlin
#
# Bestde 14 348
#
# --- Page 2 (OCR) ---
# Berufseignungsanforderungen
#
# für den Eintritt in den Lehrberuf
#
# Thermometerjustierer
# (Thermometerfchreiber)
#
# (Die Begründungen für die einzelnen Eignungsanforderungen find aus den
# Berufsanforderungen abgeleitet, wie sie sich aus dem Arbeitsgebiet, der Berufs-
# ausübung sowie den besonderen Arbeitsbedingungen des Facharbeiters ergeben.)
#
# Vorbildungsnuißige Anforderungen
#
# Notwendig: Möglichst abgeschlossene Volksfchulbildung oder
# qleichwertige Allgemeinbildnng bei Abgangern
# aus anderen Schulen:
#
# Gute Kenntnisse im Rechnen (Umrechnen) f)inreichende
# Fertigkeiten im Zeichnen und Schönschreiben
#
# Erwünfcht: Sportliche Vorbildung:
# ' Ausgleich gegen langdauerndes Sitzen und Stehen.
# Ausfchließend:Hilfs-, Sehfchwachen- nnd Blindenschulbildung.
# (Schwerhörige und Taubstumme können den Be-
# ruf ausüben).
#
# Körperliche Anforderungen
#
# Notwendig: KeinebesonderenAnforderungenand«enKörperbau. «
# Normale Sehschärfe (mindestens 2X3 beiderseits), . .
# Tiefensehen und unesingeengtes Blickfeld: z
# Genaues Einstellen der Skalen und Erkennen der Flüssig- ’
#
# keitsgrenzfläche am Thermometer.
#
# Erwünfcht: —- — —
#
# Ausfchließend:Überempfindlichkeit der Haut gegen Quecksilber,
# Flußsäure, Wachs und Ole. ·
# Lungentuberkulose (offene oder fortschreitende)
# und Kehlkopftuberkulosez andere chronische Er-
# krankungen der Lungen und der Luftwege(Tuber-
# kulofegefährdete find ausgeschlossen).
#
# --- Page 3 (OCR) ---
# ,
#
# Notwendig :
#
# Erwünscht :
#
# Chronische organische Nervenleiden mit Motili-
# tätsstörungen.
#
# slsir·belsciuleuverkrümmung 3. Grades. Starr-er
# Rundrücken.
#
# Chronische Gelenkerkrankungen mit Bewegungs-
# einschränkungen an den oberen Gliedmaßen
#
# Eifnäugigkeit (Gefährdung des einen Auges durch
# Uberanstrengung). Nicht korrigierbare Bre-
# chungsfehler der Augen, Schielen, Blickfeld-
# einengung (Skotome).
#
# Starke Schweißhände.
#
# Fehlen des Daumens an der Arbeitshand oder
# von mehr als einem Finger an jeder Hand.
#
# Seelische Anforderungen
#
# Sinn für Kleinarbeit.
#
# Saubere, gwissenhafte, ausdauernde und auf-
# merksame Arbeitsweise:
#
# Eine um Bruchteile eines Millimeters falsch eingestellte
# Marke kann wertvolle Werkstücke unbrauchbar machen.
# Beim Teilen und Schreiben einer Thermometerskala
# darf die Aufmerksamkeit nicht nachlassen, um Arbeits-«
# fehler zu vermeiden. Abweichungen von Vm mm müssen
# noch erkannt werden.
#
# Handgeschicklichkeit (inobesondere Ruhe und
# Sicherheit der Hände):
#
# Anbringen von Teilungen und Veschriftungen z. B. auf
# Glasrohr, Papier, Milchglas, Spiegelglas, Holz, Me-
# tall u. a. Stempeln.
#
# Umstellungsfähigkeit auf verschiedene Arbeiten:
#
# Der Thermometerjustierer muß sich auf gröbere und
# feinste Arbeiten umstellen können. Einfache Arbeiten der
# Glasapparate- und Aräometerjusiiererei.
#
# Ausschließend:Geringe geistige und praktische Wendigkeit.
#
# «Schwere« Hand.
#
# 🔍 Extracting all metadata...
#
# ============================================================
# EXTRACTION RESULTS:
# ============================================================
# {'title': None, 'year': 1938, 'date': '1938-11-11T00:00:00', 'publisher': None, 'author': None, 'document_type': None, 'profession': None, 'confidence_scores': {}, 'raw_text_preview': None}
# YEAR: 1938
# DATE: 1938-11-11T00:00:00
