# %%
from processor.ocr_image_processing import ImagePreprocessor
import os
import cv2

# %% [markdown]
# # Get PDF file

# %%
from pdf_extractor_with_ocr import PDFExtractorWithOCR

pdf_extractor = PDFExtractorWithOCR(debug=True)
pdf_extractor.extract_text_from_pdf(pdf_path = "pdfs/30s/30s/berufearchiv_5496.pdf", start_page=1, end_page=1)
# Out:
# ✅ PDF Extractor with OCR initialized
# ✅ Tesseract OCR is available
# 📄 Processing pages 1 to 1 of 4 ..... in berufearchiv_5496.pdf
# 📖 Processing page 1...
#       🖼️ Converting page 1 to high-quality image...
# 💾 Saved original image as 'output_dir/original_page.png'
# Text after inversion:
#    ✅ OCR extraction: 439 characters
# '\n--- Page 1 (OCR) ---\nBerufs-\nEignungsanforderungen\n\nfür den Eintritt in den Lehrberuf\n\nSchmuckstemfasser\nbearbeitet vom\n\nDeutschen Ausschuß für Technisches Schulweer (Datfch) E.V.\n· Berlin NW7\n\nim Einvernehmen\nmit der\nDeutschen Arbeitsfront\nder\n\nNeichsgruppe Industrie\n\n. und der\n\nArbeitsgemeinschaft der Industrie- und Handelskammern\nin der Neichswirtfchaftskammer\n\n(Stcmd vom 22. September 1938)\n\nVerlag von B.G.Teubner in Leipzig und Berlin\n\nPest-Nu 13 650\n'

# %%
pdf_extractor.extract_metadata
